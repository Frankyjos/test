# %%
# !aws ecr create-repository --repository-name archery-e-coach-pose-estimation-custom-image
# Out:
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-east-1:844377604406:repository/archery-e-coach-pose-estimation-custom-image",
#         "registryId": "844377604406",
#         "repositoryName": "archery-e-coach-pose-estimation-custom-image",
#         "repositoryUri": "844377604406.dkr.ecr.us-east-1.amazonaws.com/archery-e-coach-pose-estimation-custom-image",
#         "createdAt": 1738868322.604,
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": false
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 844377604406.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !docker build -t archery-e-coach-pose-estimation-custom-image .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 667B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.2s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
# [+] Building 0.2s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 667B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.2s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
# [+] Building 0.4s (7/12)                                         docker:default
# ...

# %%
# !docker tag archery-e-coach-pose-estimation-custom-image:latest 844377604406.dkr.ecr.us-east-1.amazonaws.com/archery-e-coach-pose-estimation-custom-image:latest

# %%
# !docker push 844377604406.dkr.ecr.us-east-1.amazonaws.com/archery-e-coach-pose-estimation-custom-image:latest
# Out:
# The push refers to repository [844377604406.dkr.ecr.us-east-1.amazonaws.com/archery-e-coach-pose-estimation-custom-image]
#
# bf18a086: Preparing
# 865e2e9a: Preparing
# 22b25619: Preparing
# e40d056d: Preparing
# 725ea373: Preparing
# 09de416d: Preparing
# 6f59ea72: Preparing
# 5bfff2c2: Preparing
# 1d9f72bc: Preparing
# 40c5b20b: Preparing
# 0678f346: Preparing
# d25746ca: Preparing
# 2f62fb6b: Preparing
# f78b6554: Preparing
# bc109fe1: Preparing
# 721b8b81: Preparing
# 6b3d71f7: Preparing
# 0cb6d8af: Preparing
# d142fd12: Preparing
# 74392678: Preparing
# 936c0b21: Preparing
# 69c72050: Preparing
# ace3c760: Preparing
# 24b7554d: Preparing
# 0130f851: Preparing
# 64c0a806: Preparing
# b3a1cce9: Preparing
# 9f5dead8: Preparing
# f19989ae: Preparing
# 42b2da59: Preparing
# dba6d705: Preparing
# 54eeaaf1: Preparing
# 28e0616c: Preparing
# c1b389b2: Preparing
# 61580c97: Preparing
# de5e589d: Preparing
# ...

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role

# Inicializar el cliente de SageMaker
sagemaker_client = boto3.client('sagemaker')
sagemaker_runtime = boto3.client('sagemaker-runtime')

# %%
# Obtener el rol de ejecución de SageMaker
role = get_execution_role()

# Definir la imagen de ECR
image_uri = '844377604406.dkr.ecr.us-east-1.amazonaws.com/archery-e-coach-pose-estimation-sagemaker-model:latest'
